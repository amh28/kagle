# %%
import tensorflow as tf
import numpy as np

IMG_SIZE_PX = 50
SLICE_COUNT = 20


n_classes = 2
batch_size = 10

x = tf.placeholder('float')
y = tf.placeholder('float')

keep_rate = 0.8

def conv3d(x, W):
    return tf.nn.conv3d(x, W, strides=[1,1,1,1,1], padding='SAME')

def maxpool3d(x):
    #                        size of window         movement of window as you slide about
    return tf.nn.max_pool3d(x, ksize=[1,2,2,2,1], strides=[1,2,2,2,1], padding='SAME')

def convolutional_neural_network(x):
    #                # 5 x 5 x 5 patches, 1 channel, 32 features to compute.
    weights = {'W_conv1':tf.Variable(tf.random_normal([3,3,3,1,32])),
               #       5 x 5 x 5 patches, 32 channels, 64 features to compute.
               'W_conv2':tf.Variable(tf.random_normal([3,3,3,32,64])),
               #                                  64 features
               'W_fc':tf.Variable(tf.random_normal([54080,1024])),
               'out':tf.Variable(tf.random_normal([1024, n_classes]))}

    biases = {'b_conv1':tf.Variable(tf.random_normal([32])),
               'b_conv2':tf.Variable(tf.random_normal([64])),
               'b_fc':tf.Variable(tf.random_normal([1024])),
               'out':tf.Variable(tf.random_normal([n_classes]))}

    #                            image X      image Y        image Z
    x = tf.reshape(x, shape=[-1, IMG_SIZE_PX, IMG_SIZE_PX, SLICE_COUNT, 1])

    conv1 = tf.nn.relu(conv3d(x, weights['W_conv1']) + biases['b_conv1'])
    conv1 = maxpool3d(conv1)


    conv2 = tf.nn.relu(conv3d(conv1, weights['W_conv2']) + biases['b_conv2'])
    conv2 = maxpool3d(conv2)

    fc = tf.reshape(conv2,[-1, 54080])
    fc = tf.nn.relu(tf.matmul(fc, weights['W_fc'])+biases['b_fc'])
    fc = tf.nn.dropout(fc, keep_rate)

    output = tf.matmul(fc, weights['out'])+biases['out']

    return output

much_data = np.load('muchdata-50-50-20.npy')
# If you are working with the basic sample data, use maybe 2 instead of 100 here... you don't have enough data to really do this
train_data = much_data[:-100]
validation_data = much_data[-100:]


def train_neural_network(x):
    prediction = convolutional_neural_network(x)
    cost = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=prediction,labels=y) )
    optimizer = tf.train.AdamOptimizer(learning_rate=1e-5).minimize(cost)
    
    hm_epochs = 100
    with tf.Session() as sess:
        sess.run(tf.initialize_all_variables())
        
        successful_runs = 0
        total_runs = 0
        
        for epoch in range(hm_epochs):
            print("entering epoch")
            for data in train_data:
                total_runs += 1
                try:
                    epoch_loss = 0
                    X = data[0]
                    Y = data[1]
                    #print(Y)
                    _, c = sess.run([optimizer, cost], feed_dict={x: X, y: Y})
                    epoch_loss += c
                    successful_run += 1
                except Exception as e:
                    pass
                    #print(str(e))
            
            print('Epoch', epoch+1, 'completed out of',hm_epochs,'loss:',epoch_loss)

            correct = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
            accuracy = tf.reduce_mean(tf.cast(correct, 'float'))

            print('Accuracy:',accuracy.eval({x:[i[0] for i in validation_data], y:[i[1] for i in validation_data]}))
            
        print('Done. Finishing accuracy:')
        print('Accuracy:',accuracy.eval({x:[i[0] for i in validation_data], y:[i[1] for i in validation_data]}))
        
        print('fitment percent:',successful_runs/total_runs)
        
        
train_neural_network(x)
print("finished training")
# Out:
# WARNING:tensorflow:From /home/alemh/.local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# entering epoch
# Epoch 1 completed out of 100 loss: 0.0
# Accuracy: 0.51
# entering epoch
# Epoch 2 completed out of 100 loss: 205009184.0
# Accuracy: 0.57
# entering epoch
# Epoch 3 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 4 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 5 completed out of 100 loss: 0.0
# Accuracy: 0.56
# entering epoch
# Epoch 6 completed out of 100 loss: 0.0
# Accuracy: 0.6
# entering epoch
# Epoch 7 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 8 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 9 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 10 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 11 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 12 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 13 completed out of 100 loss: 0.0
# Accuracy: 0.75
# entering epoch
# Epoch 14 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 15 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 16 completed out of 100 loss: 294279584.0
# Accuracy: 0.64
# entering epoch
# Epoch 17 completed out of 100 loss: 294812480.0
# Accuracy: 0.72
# entering epoch
# Epoch 18 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 19 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 20 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 21 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 22 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 23 completed out of 100 loss: 0.0
# Accuracy: 0.57
# entering epoch
# Epoch 24 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 25 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 26 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 27 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 28 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 29 completed out of 100 loss: 0.0
# Accuracy: 0.76
# entering epoch
# Epoch 30 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 31 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 32 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 33 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 34 completed out of 100 loss: 121100880.0
# Accuracy: 0.7
# entering epoch
# Epoch 35 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 36 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 37 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 38 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 39 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 40 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 41 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 42 completed out of 100 loss: 0.0
# Accuracy: 0.74
# entering epoch
# Epoch 43 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 44 completed out of 100 loss: 0.0
# Accuracy: 0.76
# entering epoch
# Epoch 45 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 46 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 47 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 48 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 49 completed out of 100 loss: 12007744.0
# Accuracy: 0.66
# entering epoch
# Epoch 50 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 51 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 52 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 53 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 54 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 55 completed out of 100 loss: 5538440.0
# Accuracy: 0.64
# entering epoch
# Epoch 56 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 57 completed out of 100 loss: 3558208.0
# Accuracy: 0.71
# entering epoch
# Epoch 58 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 59 completed out of 100 loss: 0.0
# Accuracy: 0.76
# entering epoch
# Epoch 60 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 61 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 62 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 63 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 64 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 65 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 66 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 67 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 68 completed out of 100 loss: 0.0
# Accuracy: 0.74
# entering epoch
# Epoch 69 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 70 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 71 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 72 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 73 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 74 completed out of 100 loss: 46931856.0
# Accuracy: 0.56
# entering epoch
# Epoch 75 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 76 completed out of 100 loss: 31585664.0
# Accuracy: 0.64
# entering epoch
# Epoch 77 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 78 completed out of 100 loss: 0.0
# Accuracy: 0.6
# entering epoch
# Epoch 79 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 80 completed out of 100 loss: 0.0
# Accuracy: 0.76
# entering epoch
# Epoch 81 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 82 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 83 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 84 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 85 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 86 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 87 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 88 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 89 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 90 completed out of 100 loss: 25700496.0
# Accuracy: 0.71
# entering epoch
# Epoch 91 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 92 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 93 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 94 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 95 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 96 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 97 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 98 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 99 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 100 completed out of 100 loss: 0.0
# Accuracy: 0.65
# Done. Finishing accuracy:
# Accuracy: 0.72
# fitment percent: 0.0
# finished training

# %%
print("hopli")
# Out:
# hopli

# %%
import tensorflow as tf
import numpy as np

IMG_SIZE_PX = 50
SLICE_COUNT = 20


n_classes = 2
batch_size = 40

x = tf.placeholder('float')
y = tf.placeholder('float')

keep_rate = 0.8

def conv3d(x, W):
    return tf.nn.conv3d(x, W, strides=[1,1,1,1,1], padding='SAME')

def maxpool3d(x):
    #                        size of window         movement of window as you slide about
    return tf.nn.max_pool3d(x, ksize=[1,2,2,2,1], strides=[1,2,2,2,1], padding='SAME')

def convolutional_neural_network(x):
    #                # 5 x 5 x 5 patches, 1 channel, 32 features to compute.
    weights = {'W_conv1':tf.Variable(tf.random_normal([3,3,3,1,32])),
               #       5 x 5 x 5 patches, 32 channels, 64 features to compute.
               'W_conv2':tf.Variable(tf.random_normal([3,3,3,32,64])),
               #                                  64 features
               'W_fc':tf.Variable(tf.random_normal([54080,1024])),
               'out':tf.Variable(tf.random_normal([1024, n_classes]))}

    biases = {'b_conv1':tf.Variable(tf.random_normal([32])),
               'b_conv2':tf.Variable(tf.random_normal([64])),
               'b_fc':tf.Variable(tf.random_normal([1024])),
               'out':tf.Variable(tf.random_normal([n_classes]))}

    #                            image X      image Y        image Z
    x = tf.reshape(x, shape=[-1, IMG_SIZE_PX, IMG_SIZE_PX, SLICE_COUNT, 1])

    conv1 = tf.nn.relu(conv3d(x, weights['W_conv1']) + biases['b_conv1'])
    conv1 = maxpool3d(conv1)


    conv2 = tf.nn.relu(conv3d(conv1, weights['W_conv2']) + biases['b_conv2'])
    conv2 = maxpool3d(conv2)

    fc = tf.reshape(conv2,[-1, 54080])
    fc = tf.nn.relu(tf.matmul(fc, weights['W_fc'])+biases['b_fc'])
    fc = tf.nn.dropout(fc, keep_rate)

    output = tf.matmul(fc, weights['out'])+biases['out']

    return output

much_data = np.load('muchdata-50-50-20.npy')
# If you are working with the basic sample data, use maybe 2 instead of 100 here... you don't have enough data to really do this
train_data = much_data[:-100]
validation_data = much_data[-100:]


def train_neural_network(x):
    prediction = convolutional_neural_network(x)
    cost = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=prediction,labels=y) )
    optimizer = tf.train.AdamOptimizer(learning_rate=1e-5).minimize(cost)
    
    hm_epochs = 100
    with tf.Session() as sess:
        sess.run(tf.initialize_all_variables())
        
        successful_runs = 0
        total_runs = 0
        
        for epoch in range(hm_epochs):
            print("entering epoch")
            for data in train_data:
                total_runs += 1
                try:
                    epoch_loss = 0
                    X = data[0]
                    Y = data[1]
                    #print(Y)
                    _, c = sess.run([optimizer, cost], feed_dict={x: X, y: Y})
                    epoch_loss += c
                    successful_run += 1
                except Exception as e:
                    pass
                    #print(str(e))
            
            print('Epoch', epoch+1, 'completed out of',hm_epochs,'loss:',epoch_loss)

            correct = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
            accuracy = tf.reduce_mean(tf.cast(correct, 'float'))

            print('Accuracy:',accuracy.eval({x:[i[0] for i in validation_data], y:[i[1] for i in validation_data]}))
            
        print('Done. Finishing accuracy:')
        print('Accuracy:',accuracy.eval({x:[i[0] for i in validation_data], y:[i[1] for i in validation_data]}))
        
        print('fitment percent:',successful_runs/total_runs)
        
        
train_neural_network(x)
print("finished training")
# Out:
# WARNING:tensorflow:From <ipython-input-1-0609faaba922>:68: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# entering epoch
# Epoch 1 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 2 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 3 completed out of 100 loss: 0.0
# Accuracy: 0.6
# entering epoch
# Epoch 4 completed out of 100 loss: 0.0
# Accuracy: 0.58
# entering epoch
# Epoch 5 completed out of 100 loss: 1210885376.0
# Accuracy: 0.64
# entering epoch
# Epoch 6 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 7 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 8 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 9 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 10 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 11 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 12 completed out of 100 loss: 34256576.0
# Accuracy: 0.68
# entering epoch
# Epoch 13 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 14 completed out of 100 loss: 0.0
# Accuracy: 0.57
# entering epoch
# Epoch 15 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 16 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 17 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 18 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 19 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 20 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 21 completed out of 100 loss: 349291392.0
# Accuracy: 0.74
# entering epoch
# Epoch 22 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 23 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 24 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 25 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 26 completed out of 100 loss: 0.0
# Accuracy: 0.56
# entering epoch
# Epoch 27 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 28 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 29 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 30 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 31 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 32 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 33 completed out of 100 loss: 0.0
# Accuracy: 0.76
# entering epoch
# Epoch 34 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 35 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 36 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 37 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 38 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 39 completed out of 100 loss: 0.0
# Accuracy: 0.57
# entering epoch
# Epoch 40 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 41 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 42 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 43 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 44 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 45 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 46 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 47 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 48 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 49 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 50 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 51 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 52 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 53 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 54 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 55 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 56 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 57 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 58 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 59 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 60 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 61 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 62 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 63 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 64 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 65 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 66 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 67 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 68 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 69 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 70 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 71 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 72 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 73 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 74 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 75 completed out of 100 loss: 0.0
# Accuracy: 0.58
# entering epoch
# Epoch 76 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 77 completed out of 100 loss: 0.0
# Accuracy: 0.6
# entering epoch
# Epoch 78 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 79 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 80 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 81 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 82 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 83 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 84 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 85 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 86 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 87 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 88 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 89 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 90 completed out of 100 loss: 0.0
# Accuracy: 0.57
# entering epoch
# Epoch 91 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 92 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 93 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 94 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 95 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 96 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 97 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 98 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 99 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 100 completed out of 100 loss: 0.0
# Accuracy: 0.67
# Done. Finishing accuracy:
# Accuracy: 0.68
# fitment percent: 0.0
# finished training

# %%
import tensorflow as tf
import numpy as np

IMG_SIZE_PX = 50
SLICE_COUNT = 20


n_classes = 2
batch_size = 20

x = tf.placeholder('float')
y = tf.placeholder('float')

keep_rate = 0.8

def conv3d(x, W):
    return tf.nn.conv3d(x, W, strides=[1,1,1,1,1], padding='SAME')

def maxpool3d(x):
    #                        size of window         movement of window as you slide about
    return tf.nn.max_pool3d(x, ksize=[1,2,2,2,1], strides=[1,2,2,2,1], padding='SAME')

def convolutional_neural_network(x):
    #                # 5 x 5 x 5 patches, 1 channel, 32 features to compute.
    weights = {'W_conv1':tf.Variable(tf.random_normal([3,3,3,1,32])),
               #       5 x 5 x 5 patches, 32 channels, 64 features to compute.
               'W_conv2':tf.Variable(tf.random_normal([3,3,3,32,64])),
               #                                  64 features
               'W_fc':tf.Variable(tf.random_normal([54080,1024])),
               'out':tf.Variable(tf.random_normal([1024, n_classes]))}

    biases = {'b_conv1':tf.Variable(tf.random_normal([32])),
               'b_conv2':tf.Variable(tf.random_normal([64])),
               'b_fc':tf.Variable(tf.random_normal([1024])),
               'out':tf.Variable(tf.random_normal([n_classes]))}

    #                            image X      image Y        image Z
    x = tf.reshape(x, shape=[-1, IMG_SIZE_PX, IMG_SIZE_PX, SLICE_COUNT, 1])

    conv1 = tf.nn.relu(conv3d(x, weights['W_conv1']) + biases['b_conv1'])
    conv1 = maxpool3d(conv1)


    conv2 = tf.nn.relu(conv3d(conv1, weights['W_conv2']) + biases['b_conv2'])
    conv2 = maxpool3d(conv2)

    fc = tf.reshape(conv2,[-1, 54080])
    fc = tf.nn.relu(tf.matmul(fc, weights['W_fc'])+biases['b_fc'])
    fc = tf.nn.dropout(fc, keep_rate)

    output = tf.matmul(fc, weights['out'])+biases['out']

    return output

much_data = np.load('muchdata-50-50-20.npy')
# If you are working with the basic sample data, use maybe 2 instead of 100 here... you don't have enough data to really do this
train_data = much_data[:-100]
validation_data = much_data[-100:]


def train_neural_network(x):
    prediction = convolutional_neural_network(x)
    cost = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=prediction,labels=y) )
    optimizer = tf.train.AdamOptimizer(learning_rate=1e-5).minimize(cost)
    
    hm_epochs = 100
    with tf.Session() as sess:
        sess.run(tf.initialize_all_variables())
        
        successful_runs = 0
        total_runs = 0
        
        for epoch in range(hm_epochs):
            print("entering epoch")
            for data in train_data:
                total_runs += 1
                try:
                    epoch_loss = 0
                    X = data[0]
                    Y = data[1]
                    #print(Y)
                    _, c = sess.run([optimizer, cost], feed_dict={x: X, y: Y})
                    epoch_loss += c
                    successful_run += 1
                except Exception as e:
                    pass
                    #print(str(e))
            
            print('Epoch', epoch+1, 'completed out of',hm_epochs,'loss:',epoch_loss)

            correct = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
            accuracy = tf.reduce_mean(tf.cast(correct, 'float'))

            print('Accuracy:',accuracy.eval({x:[i[0] for i in validation_data], y:[i[1] for i in validation_data]}))
            
        print('Done. Finishing accuracy:')
        print('Accuracy:',accuracy.eval({x:[i[0] for i in validation_data], y:[i[1] for i in validation_data]}))
        
        print('fitment percent:',successful_runs/total_runs)
        
        
train_neural_network(x)
print("finished training")
# Out:
# WARNING:tensorflow:From <ipython-input-2-387bead6c90a>:68: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# entering epoch
# Epoch 1 completed out of 100 loss: 41955456.0
# Accuracy: 0.6
# entering epoch
# Epoch 2 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 3 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 4 completed out of 100 loss: 321474752.0
# Accuracy: 0.71
# entering epoch
# Epoch 5 completed out of 100 loss: 0.0
# Accuracy: 0.54
# entering epoch
# Epoch 6 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 7 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 8 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 9 completed out of 100 loss: 651517568.0
# Accuracy: 0.67
# entering epoch
# Epoch 10 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 11 completed out of 100 loss: 445328768.0
# Accuracy: 0.64
# entering epoch
# Epoch 12 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 13 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 14 completed out of 100 loss: 70791784.0
# Accuracy: 0.57
# entering epoch
# Epoch 15 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 16 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 17 completed out of 100 loss: 645922240.0
# Accuracy: 0.66
# entering epoch
# Epoch 18 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 19 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 20 completed out of 100 loss: 203925984.0
# Accuracy: 0.71
# entering epoch
# Epoch 21 completed out of 100 loss: 197860464.0
# Accuracy: 0.6
# entering epoch
# Epoch 22 completed out of 100 loss: 20479648.0
# Accuracy: 0.59
# entering epoch
# Epoch 23 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 24 completed out of 100 loss: 152664448.0
# Accuracy: 0.65
# entering epoch
# Epoch 25 completed out of 100 loss: 23077056.0
# Accuracy: 0.64
# entering epoch
# Epoch 26 completed out of 100 loss: 0.0
# Accuracy: 0.59
# entering epoch
# Epoch 27 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 28 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 29 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 30 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 31 completed out of 100 loss: 367620352.0
# Accuracy: 0.67
# entering epoch
# Epoch 32 completed out of 100 loss: 278022368.0
# Accuracy: 0.67
# entering epoch
# Epoch 33 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 34 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 35 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 36 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 37 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 38 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 39 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 40 completed out of 100 loss: 13841280.0
# Accuracy: 0.73
# entering epoch
# Epoch 41 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 42 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 43 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 44 completed out of 100 loss: 0.0
# Accuracy: 0.6
# entering epoch
# Epoch 45 completed out of 100 loss: 71768320.0
# Accuracy: 0.66
# entering epoch
# Epoch 46 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 47 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 48 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 49 completed out of 100 loss: 0.0
# Accuracy: 0.73
# entering epoch
# Epoch 50 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 51 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 52 completed out of 100 loss: 0.0
# Accuracy: 0.72
# entering epoch
# Epoch 53 completed out of 100 loss: 0.0
# Accuracy: 0.71
# entering epoch
# Epoch 54 completed out of 100 loss: 92976208.0
# Accuracy: 0.65
# entering epoch
# Epoch 55 completed out of 100 loss: 90024992.0
# Accuracy: 0.66
# entering epoch
# Epoch 56 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 57 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 58 completed out of 100 loss: 17703392.0
# Accuracy: 0.7
# entering epoch
# Epoch 59 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 60 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 61 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 62 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 63 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 64 completed out of 100 loss: 52660256.0
# Accuracy: 0.63
# entering epoch
# Epoch 65 completed out of 100 loss: 82470208.0
# Accuracy: 0.65
# entering epoch
# Epoch 66 completed out of 100 loss: 47146416.0
# Accuracy: 0.63
# entering epoch
# Epoch 67 completed out of 100 loss: 20078592.0
# Accuracy: 0.62
# entering epoch
# Epoch 68 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 69 completed out of 100 loss: 0.0
# Accuracy: 0.6
# entering epoch
# Epoch 70 completed out of 100 loss: 18900624.0
# Accuracy: 0.64
# entering epoch
# Epoch 71 completed out of 100 loss: 0.0
# Accuracy: 0.68
# entering epoch
# Epoch 72 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 73 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 74 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 75 completed out of 100 loss: 80388880.0
# Accuracy: 0.68
# entering epoch
# Epoch 76 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 77 completed out of 100 loss: 0.0
# Accuracy: 0.61
# entering epoch
# Epoch 78 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 79 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 80 completed out of 100 loss: 13811084.0
# Accuracy: 0.67
# entering epoch
# Epoch 81 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 82 completed out of 100 loss: 25342192.0
# Accuracy: 0.63
# entering epoch
# Epoch 83 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 84 completed out of 100 loss: 0.0
# Accuracy: 0.66
# entering epoch
# Epoch 85 completed out of 100 loss: 64888016.0
# Accuracy: 0.64
# entering epoch
# Epoch 86 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 87 completed out of 100 loss: 66992504.0
# Accuracy: 0.58
# entering epoch
# Epoch 88 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 89 completed out of 100 loss: 0.0
# Accuracy: 0.69
# entering epoch
# Epoch 90 completed out of 100 loss: 0.0
# Accuracy: 0.65
# entering epoch
# Epoch 91 completed out of 100 loss: 0.0
# Accuracy: 0.67
# entering epoch
# Epoch 92 completed out of 100 loss: 25351400.0
# Accuracy: 0.62
# entering epoch
# Epoch 93 completed out of 100 loss: 7813856.0
# Accuracy: 0.61
# entering epoch
# Epoch 94 completed out of 100 loss: 0.0
# Accuracy: 0.7
# entering epoch
# Epoch 95 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 96 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 97 completed out of 100 loss: 0.0
# Accuracy: 0.64
# entering epoch
# Epoch 98 completed out of 100 loss: 0.0
# Accuracy: 0.62
# entering epoch
# Epoch 99 completed out of 100 loss: 0.0
# Accuracy: 0.63
# entering epoch
# Epoch 100 completed out of 100 loss: 0.0
# Accuracy: 0.67
# Done. Finishing accuracy:
# Accuracy: 0.64
# fitment percent: 0.0
# finished training
